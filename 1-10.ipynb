# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
h = plt.hist(np.random.default_rng().triangular(-3, 0, 8, 1000), bins=100, density=True)

#label axes
plt.ylabel("y")
plt.xlabel("x")
plt.savefig("1-10.pdf", bbox_inches="tight",facecolor="white")
